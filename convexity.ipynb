# %% [markdown]
# <a href="https://colab.research.google.com/github/kk13332488/Deep-Learning/blob/main/convexity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def sig(x):
    return 1/(1+np.exp(-x))

x = np.array([1,2,3,4,5,6])
y = np.array([0,0,0,1,1,1])
xy = np.array([[1,0],[2,0],[3,0],[4,1],[5,1],[6,1]])

n = 100
a = np.linspace(-5, 5, n)
b = np.linspace(-2.5, 2.5, n)
a, b = np.meshgrid(a, b)
cost1 = np.zeros((n, n)) # cross entropy function
for val in xy:
    temp = -val[1] * np.log(sig(a+b*val[0])) - (1-val[1]) * np.log(1-sig(a+b*val[0]))
    cost1 += temp
    print(cost1)

cost2 = np.zeros((n, n))
for val in xy:
    temp = (val[1]-sig(a+b*val[0]))**2 # error sums of squre function
    cost2 += temp
    print(cost2)

ax = plt.axes(projection='3d')
ax.contour3D(a, b, cost1, 100, cmap='binary') # satisfies convexity
# Out:
# [[5.52931475e-04 6.11683384e-04 6.76675883e-04 ... 2.39370952e+00
#   2.48591010e+00 2.57888973e+00]
#  [5.81566201e-04 6.43359723e-04 7.11716694e-04 ... 2.43970830e+00
#   2.53230660e+00 2.62565171e+00]
#  [6.11683384e-04 6.76675883e-04 7.48571371e-04 ... 2.48591010e+00
#   2.57888973e+00 2.67258499e+00]
#  ...
#  [7.15748880e-02 7.88897343e-02 8.69202039e-02 ... 7.19771827e+00
#   7.29865647e+00 7.39960158e+00]
#  [7.51466561e-02 8.28116523e-02 9.12234500e-02 ... 7.24818646e+00
#   7.34912821e+00 7.45007652e+00]
#  [7.88897343e-02 8.69202039e-02 9.57297205e-02 ... 7.29865647e+00
#   7.39960158e+00 7.50055293e+00]]
# [[5.98330375e-04 6.61907512e-04 7.32238075e-04 ... 2.99093947e+00
#   3.12982707e+00 3.27203691e+00]
#  [6.31790329e-04 6.98921915e-04 7.73184289e-04 ... 3.08362527e+00
#   3.22545378e+00 3.37057878e+00]
#  [6.67245576e-04 7.38143478e-04 8.16572001e-04 ... 3.17905728e+00
#   3.32381680e+00 3.47183514e+00]
#  ...
# ...
